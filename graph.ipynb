# %%
from src.graph import build_graph

def export_graph():
    g = build_graph()

    # Option A: Save PNG directly
    g.get_graph().draw_png("agent_flow.png")
    print("PNG exported → agent_flow.png")

    # # Option B: Save Mermaid text (for README embedding)
    # with open("agent_flow.mmd", "w", encoding="utf-8") as f:
    #     f.write(g.get_graph().draw_mermaid())
    # print("Mermaid exported → agent_flow.mmd")

if __name__ == "__main__":
    export_graph()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File e:\HashimEdisk\EndToEndProjects\AgenticAIWorkspace\langgraph_env\Lib\site-packages\langchain_core\runnables\graph_png.py:138, in PngDrawer.draw(self, graph, output_path)
#     137 try:
# --> 138     import pygraphviz as pgv  # type: ignore[import-not-found]
#     139 except ImportError as exc:
#
# ModuleNotFoundError: No module named 'pygraphviz'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 16
#      10     # # Option B: Save Mermaid text (for README embedding)
#      11     # with open("agent_flow.mmd", "w", encoding="utf-8") as f:
#      12     #     f.write(g.get_graph().draw_mermaid())
#      13     # print("Mermaid exported → agent_flow.mmd")
#      15 if __name__ == "__main__":
# ...

# %%
# !pip install pygraphviz
# Out:
# ...
#   Using cached pygraphviz-1.14.tar.gz (106 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build pygraphviz
#   error: subprocess-exited-with-error
#
#   × Building wheel for pygraphviz (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [88 lines of output]
#       C:\Users\PMLS\AppData\Local\Temp\pip-build-env-rjhkqnpn\overlay\Lib\site-packages\setuptools\config\_apply_pyprojecttoml.py:82: SetuptoolsDeprecationWarning: `project.license` as a TOML table is deprecated
#       !!
#
#               ********************************************************************************
# ...
